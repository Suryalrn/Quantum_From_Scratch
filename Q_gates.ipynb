# %%
import numpy as np


class Notation:
    def __init__(self,vector):
        self.k = 

    def __str__(self):
        return {}
        pass
class gates:
    x = np.array([[0,1],
                  [1,0]])
    y = np.array([[0,-1i],
                  [1i,0]])
    z = np.array([[1,0],
                 [0,-1]])
    h = (1/(np.sqrt(2)))*np.array([[1,1],
                                   [1,-1]])
    

    def __init__(self):
        self.ket_0 = np.array([1,0])
        self.ket_1 = np.array([[0],[1]])
        self.Bra_0 = self.ket_0.conj().T
        self.Bra_1 = self.ket_1.conj().T
